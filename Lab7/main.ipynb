# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import cv2
from skimage.feature import local_binary_pattern

# %% [markdown]
# ### LBP

# %%
def apply_lbp(
    img_path: str,
    radius: int,
    num_points: int,
    method: str
) -> np.ndarray:
    
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    lbp = local_binary_pattern(img, P, R, METHOD)
    fig = plt.figure(figsize=(8, 6))
    ax = fig.add_subplot(1, 1, 1)
    ax.hist(lbp.ravel(), density=True, bins=n_bins, range=(0, n_bins), facecolor='0.5')
    ax.set_title(f'LBP histogram for R:{R}, P:{P}, Method:{METHOD}')
    plt.show()
    
    return lbp.ravel()

# %%
feature_vector =
